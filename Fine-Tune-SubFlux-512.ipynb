# %% [markdown]
# # Training

# %%
# !accelerate launch \
    script/train_controlnet_flux_4bit_Normal.py \
    --pretrained_model_name_or_path base_model/FLUX.1-dev \
    --jsonl_for_train datasets/set_2/json_sub_people/train_data_TTRS2.json \
    --output_dir output/model_TTRS2_NORMAL \
    --train_batch_size 1 \
    --gradient_accumulation_steps 1 \
    --learning_rate 5e-6 \
    --lr_scheduler cosine \
    --lr_warmup_steps 500 \
    --max_train_steps 150000 \
    --resolution 512 \
    --max_grad_norm 1.0 \
    --adam_weight_decay 0.01 \
    --num_double_layers=2 \
    --num_single_layers=1 \
    --controlnet_mode 4 \
    --checkpointing_steps 10000 \
    --mixed_precision bf16 \
    --save_weight_dtype bf16 \
    --gradient_checkpointing \
    --use_8bit_adam \
    --set_grads_to_none \
    --seed 42 \
    --resume_from_checkpoint "latest"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 02/18/2025 20:24:08 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:10<00:00,  5.00s/it]
# ...

# %%
# !accelerate launch --config_file "accelerate_config_zero3.yaml" script/train_controlnet_flux.py \
#     --pretrained_model_name_or_path=base_model/FLUX.1-dev \
#    --controlnet_model_name_or_path adapter_model/FLUX.1-dev-Controlnet-Union\
#     --jsonl_for_train=datasets/dataset.jsonl \
#     --conditioning_image_column=conditioning_image \
#     --image_column=image \
#     --caption_column=text \
#     --tracker_project_name=flux_train_controlnet \
#     --output_dir=outpu \
#     --max_train_steps=300 \
#     --mixed_precision bf16 \
#     --checkpointing_steps=30 \
#     --gradient_accumulation_steps=8 \
#     --resolution=512 \
#     --train_batch_size=1 \
#     --learning_rate=1e-5 \
#     --num_double_layers=4 \
#     --num_single_layers=0 \
#     --gradient_checkpointing
